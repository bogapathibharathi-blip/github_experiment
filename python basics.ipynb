# %%
print(bool("hello"))
print(bool(15))
# Out:
# True
# True

# %%
x="hello"
y=15

print(bool(x))
print(bool(y))
# Out:
# True
# True

# %%
bool("abc")
bool(123)
print("apple","banana")
# Out:
# apple banana

# %%
bool(False)
bool(None)
bool(0)
bool("")
bool(())
bool([])
bool({})
# Out:
# False

# %%
class myclass():
  def __len__(self):
      return 0

myobj=myclass()
print(bool(myobj))
# Out:
# False

# %%
def myFunction() :
    return True
print(myFunction())
# Out:
# True

# %%
def myFunction() :
    return True

if myFunction():
    print("YES")
else:
    print("NO")
# Out:
# YES

# %%
x=200
print(isinstance(x,int))
# Out:
# True

# %%
10>9
10==9
bool("hello")
bool(0)
# Out:
# False

# %%
#python operators
print(50+10)
# Out:
# 60

# %%
sum1=100+50
sum2=sum1+250
sum3=sum2+sum2

# %%
sum1 = 100 + 50      # 150 (100 + 50)
sum2 = sum1 + 250    # 400 (150 + 250)
sum3 = sum2 + sum2   # 800 (400 + 400)

# %%
#arithematic operatora
a=10
b=20

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)
print(a//b)
# Out:
# 30
# -10
# 200
# 0.5
# 10
# 100000000000000000000
# 0

# %%
numbers=[1,2,3,4,5]

if (count := len(numbers)) > 3:
    print(f"list has {count}elements")
# Out:
# list has 5elements

# %%
#comparison operator 
x=5
y=10

print(x==y)
print(x!=y)
print(x>y)
print(x<y)
print(x<=y)
print(x>=y)
# Out:
# False
# True
# False
# True
# True
# False

# %%
x=5

print(1 < x < 10)
print(1 < x and x < 10)
# Out:
# True
# True

# %%
x = 5

print(not(x >3 and x < 10))
# Out:
# False

# %%
x=["apple","banana"]
y=["apple", "banana"]
z=x
print(x is z)
print(x is not y)
# Out:
# True
# True

# %%
x=[1,2,3]
y=[1,2,3]

print(x==y)
print(x is y)
# Out:
# True
# False

# %%
#membership operator
fruits= ["apple","banana","cherry"]

print("banana" in fruits)
# Out:
# True

# %%
fruits= ["apple","banana","cherry"]

print("pineapple" not in fruits)
# Out:
# True

# %%
a="Hello,world!"

print("H" in a)
print("hello" in a)
print("w" not in a)
print("l" in a)
# Out:
# True
# False
# False
# True

# %%
#bitwise operatots
print(6&3)
# Out:
# 2

# %%
print(6 | 3)
# Out:
# 7

# %%
print(6^3)
# Out:
# 5

# %%
print((6+3)-(6+3))
# Out:
# 0

# %%
print(100+5*3)
# Out:
# 115

# %%
print(5+4-7+3)
# Out:
# 5

# %%
a=15
b=4

print(a%b)
print(a//b)
print(a**b)
a+=10
print(a)
print(b)
# Out:
# 3
# 3
# 50625
# 25
# 4

# %%
#assignment operator
numbers = [1,2,3,4,5]
print("number of elements")
if (cuont := len(numbers)) > 3:
    print(f"list has {count} elements")
# Out:
# number of elements
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 print("number of elements")
#       4 if (cuont := len(numbers)) > 3:
# ----> 5     print(f"list has {count} elements")
#
# NameError: name 'count' is not defined

# %%
#list
mylist=["apple", "banana", "cherry"]

# %%
thislist=["apple", "banana", "cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
#allow duplicates
thislist=["apple","banana","cherry", "apple", "cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'apple', 'cherry']

# %%
#list lenght
thislist=["apple", "banana","cherry"]
print(len(thislist))
# Out:
# 3

# %%
#list items-data types
list1=["apple","banana","cherry"]
list2=[1,2,4,6,5,]
list3=[True,False,False]
print(list1)
print(list2)
print(list3)
# Out:
# ['apple', 'banana', 'cherry']
# [1, 2, 4, 6, 5]
# [True, False, False]

# %%
list=["abc",34,True,40,"male"]
print(list1)
# Out:
# ['apple', 'banana', 'cherry']

# %%
mylist=["Apple","Banana","Cherry"]
print(len(mylist))
# Out:
# 3

# %%
thilist=["apple", "Banan","Cherry"]
print(thilist)
# Out:
# ['apple', 'Banan', 'Cherry']

# %%
#access List Items
thislist=["Apple","Banana","CHerry"]
print(thislist[1])
print(thislist[2])
print(thislist[0])
# Out:
# Banana
# CHerry
# Apple

# %%
thilist=["Apple","Banana","Cherry"]
'print(thislist[-1])
# Out:
# CHerry

# %%
thislist=["Apple","Banana","Cherry","mango","orange","kivi"]
print(thislist[2:3])
# Out:
# ['Cherry']

# %%
a=["apple","banana","cherry","mango","kivi","banana"]
print(a[:4])
# Out:
# ['apple', 'banana', 'cherry', 'mango']

# %%
a=["Apple","Banana","Cherry","mango","kivi"]
print(a[:2])
# Out:
# ['Apple', 'Banana']

# %%
a=["apple","banana","cherry","mango","kivi"]
print(a[-4:-2])
# Out:
# ['banana', 'cherry']

# %%
a=["apple","banana","cherry","mango","kivi"]
if "apple" in a:
    print("yes, 'apple' in the fruits list" )
# Out:
# yes, 'apple' in the fruits list

# %%
#change item value
thislist=["apple","banana","cherry"]
thislist[1]="blackcurrant"
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'cherry']

# %%
a=[1,2,3,4,5,6]
a[1:3]=[10,11]
print(a)
# Out:
# [1, 10, 11, 4, 5, 6]

# %%
thislist=["apple","banana","cherry"]
thislist[1:3]=["mango"]
print(thislist)
# Out:
# ['apple', 'mango']

# %%
thislist=["apple","banana","cherry"]
thislist.insert(2, "mango")
print(thislist)
#o/p:-['apple','banana','mango','cherry']
# Out:
# ['apple', 'banana', 'mango', 'cherry']

# %%
thislist=["apple","banana","cherry"]
thislist.append("orange")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
thislist=["apple","banana","cherry"]
thislist.insert(1, "mango")
print(thislist)
# Out:
# ['apple', 'mango', 'banana', 'cherry']

# %%
thislist=["apple"]
tropical=["banana"]
thislist.extend(tropical)
print(thislist)
# Out:
# ['apple', 'banana']

# %%
a=[1,2,3,4,5]
b=[6,7,8,9]
a.extend(b)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
a=["apple","banana","cherry"]
a.remove("apple")
print(a)
# Out:
# ['banana', 'cherry']

# %%
a=["apple","banana","cherry"]
a.pop(1)
print(a)
# Out:
# ['apple', 'cherry']

# %%
thislist=["apple","banana","cherry"]
del thislist[0]
print(thislist)
# Out:
# ['banana', 'cherry']

# %%
thislist=["apple","banana","cherry"]
thislist.clear()
print(thislist)

thislist=["apple","banana"]
print(type(thislist))
# Out:
# []
# <class 'list'>

# %%
#tuple''''''

mytuple=("apple","banana","cherry")
print(mytuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
thistuple=("banana","apple","cherry")
print(len(thistuple))
# Out:
# 3

# %%
thistuple=("apple")
print(type(thistuple))
# Out:
# <class 'str'>

# %%
t1=("apple","banana","cherry")
t2=(1,2,3,4,5)
t3=(True,False,False)
print(t1)
print(t3)
print(t2)
# Out:
# ('apple', 'banana', 'cherry')
# (True, False, False)
# (1, 2, 3, 4, 5)

# %%
t=("abc",34,True,40,"male")
print(t)
# Out:
# ('abc', 34, True, 40, 'male')

# %%
tuple=("apple")
print(type(tuple))
# Out:
# <class 'str'>

# %%
mytuble=("apple","banana","cherry")
print(type(mytuple))
# Out:
# <class 'tuple'>
