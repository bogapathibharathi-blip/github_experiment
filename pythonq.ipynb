# %%
t=6,8,9
type(t)
# Out:
# tuple

# %%
t=(6,8,9)
print(type(t))
# Out:
# <class 'tuple'>

# %%
s={}
type(s)
# Out:
# dict

# %%
l=[9,0,67,0,8,8] # how to remove duplicate values
set(l)
# Out:
# {0, 8, 9, 67}

# %%
s={89,90,6,'p',788888,4556,9}
s
# Out:
# {4556, 6, 788888, 89, 9, 90, 'p'}

# %%
s={89,90,6,'p',788888,4556,9,(8,88)}
s
# Out:
# {(8, 88), 4556, 6, 788888, 89, 9, 90, 'p'}

# %%
s=[89,90,6,'p',788888,4556,9]
s[0]=9
s
# Out:
# [9, 90, 6, 'p', 788888, 4556, 9]

# %%
s={9,9,0}
s.add(7)
s
# Out:
# {0, 7, 9}

# %%
s={9,9,0}
s.update([7,0,9])
s
# Out:
# {0, 7, 9}

# %%
s={9,9,0}
s.add((8,9,0))
s
# Out:
# {(8, 9, 0), 0, 9}

# %%
s={9,9,0}
s.add(7)
s

# %%
# i want to delete value
s={5,8,9}
s.remove(9)
s
# Out:
# {5, 8}

# %%
s={5,8,9}
s.discard(9)
s
# Out:
# {5, 8}

# %%
s={5,8,9}
s.discard(90) # no error
s
# Out:
# {5, 8, 9}

# %%
s={7,90,6}
s.pop()
# Out:
# 90

# %%
s.pop()
# Out:
# 6

# %%
l=[7,980,98]
l.pop()
# Out:
# 98

# %%
l=[7,980,98]
l.pop(0)
# Out:
# 7
