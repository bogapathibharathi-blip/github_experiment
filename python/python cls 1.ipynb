# %% [markdown]
# # PYTHON

# %% [markdown]
# python is a versatile, high-level programming language known for its simple syntax and readability.

# %% [markdown]
# # KEYWORD

# %% [markdown]
# keywords are" reserved word "in python that have a purpose

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # identifiers

# %% [markdown]
# An identifier is a name used to identify program elements (or)
#
# An identifier is a name used to identify a variable in python

# %%
a=20

# %%
a
# Out:
# 20

# %%
name=200

# %%
name
# Out:
# 200

# %% [markdown]
# 1.Identifier cannot start with digit
#
# 1.Identifier cannot start use keywords
#
# 1.Identifier cannot start use special characters can use_

# %%
a=100

# %%
a
# Out:
# 100

# %%
a2=100

# %%
a2
# Out:
# 100

# %%
if=200
# Out:
#   Cell In[1], line 1
#     if=200
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# # commants

# %% [markdown]
# Comments can be used to explain the code for more readability
#
# We have 2 types of comments
#
# 1.single line comments
#
# 2.multiline comments-""" """"/'''  '''

# %%
100+500 #adding
# Out:
# 600

# %%
""" this is used to
the
multiline comments"""
a=500
a
# Out:
# 500

# %%
b=500
b
# Out:
# 500

# %% [markdown]
# # Data types

# %% [markdown]
# A data type specifies the type of value that a variable can store
#
# Data types tell python what kind of data is stored variable
#
# types of data
#
# 1. Numbers
#
# a) Integer int whole numbers (1,100,32)
#
# b)float desimal numbers (53.8, 100.43,1999.63)
#
# c)complex numbers where we will be having imaginary number, imaginary unit and real number(5i+75, 65+2j)
#
# 2.Strings It stored text data enclosed with quotes('name", "john")
#
# 3.Boolean It stored only two values (True, False)

# %%
a=20

# %%
b=3.4

# %%
c=3+5j

# %%
d=True

# %%
e="sree"

# %%
print(a)
print(b)
print(c)
print(d)
print(e)

print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# 20
# 3.4
# (3+5j)
# True
# sree
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'bool'>
# <class 'str'>

# %%
a=True
print(a)
print(type(a))
# Out:
# True
# <class 'bool'>

# %%
e="sree"
print(e)
print(type(e))
# Out:
# sree
# <class 'str'>

# %%
a=600
type(a)
# Out:
# int

# %%
float(a)
# Out:
# 600.0

# %%
b=float(a)
print(b)
type(b)
# Out:
# 600.0
# float

# %%
c=str(a)
print(c)
type(c)
# Out:
# 600
# str

# %%
d=bool(a) # only o is considered as false except that everything is True(-ve's and +ve's)
print(d)
type(d)
# Out:
# True
# bool

# %%
e=-100

# %%
bool(e)
# Out:
# True

# %%
g=0

# %%
bool(g)
# Out:
# False

# %%
f=673.7

# %%
int(f)
# Out:
# 673

# %%
str(f)
# Out:
# '673.7'

# %%
bool(f)
# Out:
# True

# %%
complex(f)
# Out:
# (673.7+0j)

# %%
str(f)
# Out:
# '673.7'

# %%
g="sree"

# %%
int(g)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 int(g)
#
# ValueError: invalid literal for int() with base 10: 'sree'

# %%
i=True

# %%
float(i)
# Out:
# 1.0

# %%
int(i)
# Out:
# 1

# %%
complex(i)
# Out:
# (1+0j)

# %%
j=8+oj
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 j=8+oj
#
# NameError: name 'oj' is not defined

# %%
int(j)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 int(j)
#
# NameError: name 'j' is not defined

# %% [markdown]
# # Sring Functions

# %% [markdown]
# String indexing is the process of accessing the individual characters of a string using their position number.
#
#                                     (or)
#
# String indexing means finding or accessing a character from a string using its position.
#
# -> two types of indexing
#
# 1.positive indexing-starts from 0 left to right.
#
# 2.negative indexing-starts from -1 right to left.

# %%
z="HELLO PYTHON"

# %%
z[2]
# Out:
# 'L'

# %%
z[5]
# Out:
# ' '

# %%
z[10]
# Out:
# 'O'

# %%
z[-2]
# Out:
# 'O'

# %%
z[-6]
# Out:
# 'P'

# %% [markdown]
# # String slicing

# %% [markdown]
# String slicing is the process of extracting apart from a sring using index positions
#                            or
# slicing means talking a portion of a string

# %% [markdown]
# syntax - string[start:end]

# %%
z="HELLO PYTHON"

# %%
z[2:8]
# Out:
# 'LLO PY'

# %%
z[6:12]
# Out:
# 'PYTHON'

# %%
z[3]
# Out:
# 'L'

# %%
z[6:] # empty end value  means python goes till end
# Out:
# 'PYTHON'

# %%
z[:9] # empty end value  means python starts from 0 index
# Out:
# 'HELLO PYT'

# %%
z[:] #entire string will be printed
# Out:
# 'HELLO PYTHON'

# %% [markdown]
# syntax step- string[start:end:step] # step means number of times it should jumb

# %%
z="HELLO PYTHON"

# %%
z[-12:-1:3]
# Out:
# 'HLPH'

# %%
z[-12:-1:3]
# Out:
# 'HLPH'

# %%
z[-12:-1:-3]
# Out:
# ''

# %%
z[-7:-1:3]
# Out:
# ' T'

# %%
z[::-1]
# Out:
# 'NOHTYP OLLEH'

# %%
z[0::]
# Out:
# 'HELLO PYTHON'

# %%
z[9:1:-2]
# Out:
# 'HY L'

# %%
y="practice coding daily to improve your skills"

# %%
y[0:8]
# Out:
# 'practice'

# %%
y[9:15]
# Out:
# 'coding'

# %%
y[16:21]
# Out:
# 'daily'

# %%
y[9:1:-2]
# Out:
# 'ceic'

# %%
y[0:25:3]
# Out:
# 'pccci i  '

# %%
y[-1:-20:-1]
# Out:
# 'slliks ruoy evorpmi'

# %%
y[-24:8:-3]
# Out:
# 'yagd'

# %%
y[25:37:2]
# Out:
# 'ipoeyu'

# %%
y[-1:-12:-2]
# Out:
# 'slk uy'

# %%
y[-35:-29]
# Out:
# 'coding'

# %% [markdown]
# # count()
# It counts the number of occurences of a given substring.

# %%
fruits="apple,banana"

# %%
fruits
# Out:
# 'apple,banana'

# %%
fruits.count('a')
# Out:
# 4

# %%
fruits.count('p')
# Out:
# 2

# %%
fruits.count('n')
# Out:
# 2

# %%
fruits.count('B')
# Out:
# 0

# %% [markdown]
# # upper()
# converts all charecters into uppercase.

# %%
text="python is acomputer language"

# %%
text.upper()
# Out:
# 'PYTHON IS ACOMPUTER LANGUAGE'

# %%
text_1="machine learnig is powerful"

# %%
text_1.upper()
# Out:
# 'MACHINE LEARNIG IS POWERFUL'

# %% [markdown]
# # lower()
# converts all charecters into lowercase.

# %%
text_2="DATA ANALYTICS IS UNDERSTANDING THE DATA"

# %%
text_2.lower()
# Out:
# 'data analytics is understanding the data'

# %% [markdown]
# # capitalize()
# makes only the first letter uppercase.

# %%
text_2.capitalize()
# Out:
# 'Data analytics is understanding the data'

# %%
text_1.capitalize()
# Out:
# 'Machine learnig is powerful'

# %% [markdown]
# # title()
# makes the fisrt letter of every word uppercase().

# %%
text_2="DATA ANALYTICS IS UNDERSTANDING THE DATA"

# %%
text_2.title()
# Out:
# 'Data Analytics Is Understanding The Data'

# %% [markdown]
# # replace()
# Replace one word with another word
#
# SYNTAX-Replace("old value","new value")

# %%
text_3="I like java programming"

# %%
text_3.replace("java","python")
# Out:
# 'I like python programming'

# %%
text_4="Hi, Good morning everyone"#replace morning with Evening

# %%
text_4.replace("morning","evening")
# Out:
# 'Hi, Good evening everyone'

# %%
text_2="DATA ANALYTICS IS UNDERSTANDING THE DATA"

# %% [markdown]
# # len()
# Returns the total number of charecters in a string

# %%
text_6="machine learning"

# %%
print(len(text_6))
# Out:
# 16

# %%
text_2="DATA ANALYTICS IS UNDERSTANDING THE DATA"

# %%
print(len(text_2))
# Out:
# 40

# %%
# split
Splits a string into alist of words

# %%
text_7="one two three four five six seven eight nine ten twelve"

# %%
text_7
# Out:
# 'one two three four five six seven eight nine ten twelve'

# %%
text_7.split()
# Out:
# ['one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'twelve']

# %%
text_7.split("e")
# Out:
# ['on',
#  ' two thr',
#  '',
#  ' four fiv',
#  ' six s',
#  'v',
#  'n ',
#  'ight nin',
#  ' t',
#  'n tw',
#  'lv',
#  '']

# %%
text_7.split("o")
# Out:
# ['', 'ne tw', ' three f', 'ur five six seven eight nine ten twelve']

# %% [markdown]
# # strip()
# Removes spaces from both ends of a string
# # lstrip()
# Removes spaces from left side of a string
# # rstrip
# Removes spaces from right side of a string

# %%
text_8="              hello everyone"

# %%
text_8.strip()
# Out:
# 'hello everyone'

# %%
text_8.rstrip()
# Out:
# '              hello everyone'

# %%
text_8.lstrip()
# Out:
# 'hello everyone'

# %%
text_9="****************Hi,good morning*************"

# %%
text_9.lstrip("*")
# Out:
# 'Hi,good morning*************'

# %% [markdown]
# # string concatenation
# It is the process of combining 2 or more things into asingle string.

# %%
city="benguluru"
state="karnataka"

# %%
print(city+state)
# Out:
# bengulurukarnataka

# %%
print(city+ "," +state)
# Out:
# benguluru,karnataka

# %%
print(city+ " " +state)
# Out:
# benguluru karnataka

# %%
first_name="Rahul"
last_name="Kumar"
print(first_name+last_name)
# Out:
# RahulKumar

# %%
print(first_name+ " "+last_name)
# Out:
# Rahul Kumar

# %% [markdown]
# # Typecasting
# Converting one data type to another data type.
#
# 1.Auto typecasting - Python automatically converts a data type
#
# 2.Forced typecasting - programmer manually/forcefully converts from one data type to another data type

# %%
a_1= 4+6.7+True

# %%
a_1
# Out:
# 11.7

# %%
a_2="data"+8
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[259], line 1
# ----> 1 a_2="data"+8
#
# TypeError: can only concatenate str (not "int") to str

# %%
a_3=10+7.8+False+True

# %%
a_3
# Out:
# 18.8

# %%
a_4=67
complex(a_4) #fourcefully typecasting
# Out:
# (67+0j)

# %%
str(a_4)
# Out:
# '67'

# %%
float(a_4)
# Out:
# 67.0

# %%
bool(a_4)
# Out:
# True

# %% [markdown]
# # operators
# 1.Arithemtic-addition(+),subsrtaction(-),multiplication(*),divition(/),floor divition(//),module(%),power(**).
#
# 2.COMPARISION-greater than(>),less than(<),less than equal to(<=),greater than equal to(>=),equal to(==),not equal to(!=)
#
# 3.LOGICAL-AND() False dominant even through one conditionturns to be false overall output will be false
# OR-False dominant even through one conditionturns true to be overall output will be true
# NOT

# %%
a=17
b=4

# %%
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a**b)
print(a%b)
# Out:
# 21
# 13
# 68
# 4.25
# 4
# 83521
# 1

# %%
a>b
# Out:
# True

# %%
a<b
# Out:
# False

# %%
a<=b
# Out:
# False

# %%
a>=b
# Out:
# True

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
#logical operator

# %%
3>1 and 15<23
# Out:
# True

# %%
3>1 and 15>23
# Out:
# False

# %%
3>1 and 15<23 and 4==4
# Out:
# True

# %%
78<90 and 78==78 and 5!=7 and 76>75
# Out:
# True

# %%
8<90 or 78==78 or 5!=7 or 76>75
# Out:
# True

# %%
8<90 or 78!=78 or 5!=7 or 76>75
# Out:
# True

# %%
100<300 or 5==6 and 14!=67
# Out:
# True

# %%
15!=15 or 7==8 and 67<100
# Out:
# False

# %%
#not

# %%
65==65
# Out:
# True

# %%
not 65==65
# Out:
# False

# %%
not 100<800
# Out:
# False

# %% [markdown]
# # If conditions
# 1. IF -The if statement is used to excecute a black of code only when a specifeid condition is True
#
# 2. IF-ELSE- the if statement is used to excecute a block of code when a condition is true and another block of code when a condition is False
#
# SYNTAX-
#
#  If condition:
#    statement1
#  else:
#    stement2
#
# 3. IF-ELIF- if
#
#  SYNTAX-
#    IF condition:
#       statement1
#    elifcondition:
#       statement2
#    elif condition:
#
# 6. IF-ELIF ELSE

# %%
vote=67
if vote >= 18:
    print("Eligible")
# Out:
# Eligible

# %%
# check whether 6 is positive or not

# %%
num=6
if num >0:
  print( "positive")
# Out:
# positive

# %%
#check whether student is pass or fail the marks is 67

# %%
marks =67
if marks >=35:
    print("pass")
# Out:
# pass

# %%
# If else

# %%
# the person is eligible for the  voting or not

# %%
vote=10
if vote >= 18:
    print("Eligible to vote")
else:
    print("not Eligible to vote")
# Out:
# not Eligible to vote

# %%
 # check 90 is positive or negative by using  if else
num_1=90
if num_1 < 0:
  print(" the number is negative")
else:
  print(" the number is positive")
# Out:
#  the number is positive

# %%
#check whether the number is odd or not

# %%
number=87
if number !=0:
    print("number is odd")
else:
    print("number is even")
# Out:
# number is odd

# %%
#check whether the number 32 is even or odd

# %%
number=32
if number % 2==0:
    print(" the number is even")
else:
    print(" the number is odd")
# Out:
#  the number is even

# %%
# check whether the number is +ve or -ve or zero

# %%
a=0

if a>0:
    print("the a is positive")
elif a<0:
    print("the a is negative")
elif a==0:
    print("the a is zero")
# Out:
# the a is zero

# %%
#check the color of traffic sinal the color is yellow

# %%
color= "yellow"

if color =='red':
   print("STOP")
elif color =='yellow':
    print("READY")
elif color == 'green':
    print("GO")
# Out:
# READY

# %%
color= "blue"

if color =='red':
   print("STOP")
elif color =='yellow':
    print("READY")
elif color == 'green':
    print("GO")
else:
    print("invalid color")
# Out:
# invalid color

# %% [raw]
# #.grade calculator
# 1.90 and above-grade a
# 2.75 to 89 -grade b
# 3.60 to 24 -grade c
# below 60 t0 grade d

# %% [raw]
# take a salary as input
# 1.salary is greater then or equal to 50000-high salary
# 2.salary is greater then or equal to 50000-medium salary
# otherwise-low salary

# %% [raw]
# day finder
# take a number from 1-7
# 1- monday 2-tuesdat 3-wedneday 4- thursday, 5-friday ...

# %% [raw]
# ATM balence check
# take a balence amount
# 1. balance is greater then 2000 -withdrawl allowed
# 2. balance is less than 0- insufficient balance
# 3.balance is less than 2000- withdrawl no allowed

# %%
marks = int(input("Enter marks: "))

if marks >= 90:
    print("Grade A")
elif marks >= 75:
    print("Grade B")
elif marks >= 60:
    print("Grade C")
else:
    print("Grade D")

# %%
#.grade calculator
1.90 and above-grade a
2.75 to 89 -grade b
3.60 to 24 -grade c
below 60 t0 grade d
